# %% [markdown]
# <a href="https://colab.research.google.com/github/imranmurtaza110/RL_Lunar_lander/blob/main/lunar_lander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium
# !pip install swig
# !apt-get install -y python-box2d
# !pip install gymnasium[box2d]
# !pip install pyvirtualdisplay
# !apt-get update
# !apt-get install -y xvfb
# !apt-get update
# !apt-get install -y xvfb python-opengl ffmpeg swig

# %%
from pyvirtualdisplay import Display
from IPython.display import display as ipy_display, HTML
from base64 import b64encode
display = Display(visible=0, size=(1400, 900))
display.start()

from gymnasium.wrappers import RecordVideo

# %%
import gymnasium as gym

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class DeepQLearning(nn.Module):
  def __init__(self):
      super().__init__()
      self.model = nn.Sequential(
            nn.Linear(8, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 4)
        )

  def forward(self, x):
    return self.model(x)

# %%
class LossFunction:
  def __init__(self, model):
        self.model = model
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)

  def step(self, loss):
      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()

# %%
import numpy as np
import random

class Agent:
  def __init__(self, action_space, observation_space, model):
    self.action_space = action_space
    self.observation_space = observation_space
    self.epsilon = 0.1
    self.epsilon_decay = 0.00005
    self.experience_buffer = []
    self.model = model
    self.optimizer = LossFunction(self.model)


  def select_action(self, state):
    if np.random.random() < self.epsilon:
        return np.random.randint(self.action_space)
    else:
        if not state[1]:
          state_tensor = torch.FloatTensor(state[0][0:8]).unsqueeze(0)
        else:
          state_tensor = torch.FloatTensor(state).unsqueeze(0)

        act_values = self.model(state_tensor)
        return torch.argmax(act_values).item()


  def experience_replay_buffer(self, state, action, reward, next_state, done):
      self.experience_buffer.append((state, action, reward, next_state, done))


  def play(self, batch_size, gamma):
        if len(self.experience_buffer) < batch_size:
            return

        batch = random.sample(self.experience_buffer, batch_size)

        states = []
        actions = []
        rewards = []
        next_states = []
        is_done = []

        for experience in batch:
            state, action, reward, next_state, done = experience
            states.append(experience[0])
            actions.append(experience[1])
            rewards.append(experience[2])
            next_states.append(experience[3])
            is_done.append(experience[4])

        states_flat = []
        for entry in states:
            if isinstance(entry, tuple) and len(entry) == 2:  # Check if entry is a nested tuple
                states_flat.append(entry[0])  # Append the array from the nested tuple
            else:
                states_flat.append(entry)  # Otherwise, append the array directly

        # Convert states_flat to tensor
        states_tensor = torch.tensor(states_flat, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.long)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        next_states = torch.tensor(next_states, dtype=torch.float32)
        is_done = torch.tensor(is_done, dtype=torch.float32)

        q_values = self.model(states_tensor)
        next_q_values = self.model(next_states)

        target_q_values = self.calculate_q_values(rewards, gamma, next_q_values, is_done)

        loss = nn.MSELoss()(q_values[range(batch_size), actions], target_q_values)

        self.optimizer.step(loss)
        self.epsilon -= self.epsilon_decay

  # bellman equation
  def calculate_q_values(self, rewards, gamma, next_q_values, is_done):
    target_q_values = []
    for i in range(len(rewards)):
        if is_done[i] == 0:
            target_q = rewards[i]
        else:
            target_q = rewards[i] + gamma * torch.max(next_q_values[i]) * (1 - is_done[i])

        target_q_values.append(target_q)
    target_q_values = torch.tensor(target_q_values)
    return target_q_values

# %%
# Create the environment
import time
env = gym.make("LunarLander-v2", render_mode="rgb_array")
video_folder = "/content/videos"

observation_shape = env.observation_space.shape

num_actions = env.action_space.n
model = DeepQLearning()

# Initialize the agent
agent = Agent(num_actions, observation_shape, model)

# Main loop
steps = []
total_episodes = []
individual_rewards = []
commulative_rewards = []
time_limit_seconds = 30

for i in range(1000):
    # if i % 10 == 0:
      # folder = video_folder + f"/episode_{1}"
      # env = RecordVideo(env, video_folder = folder, name_prefix=f"episode_{i+1}")
    state = env.reset()
    total_reward = 0
    start_time = time.time()
    for j in range(200000):  # Maximum episode length
        action = agent.select_action(state)

        next_state, reward, done, _, _ = env.step(action)
        agent.experience_replay_buffer(state, action, reward, next_state, done)
        state = next_state
        agent.play(batch_size=32, gamma=0.99)
        total_reward += reward

        elapsed_time = time.time() - start_time

        # if i > 50:
        #   if j % 50 == 0:
        #     print('episode: ' + str(i))
        #     print('iteration: ' + str(j))
        #     print('action: ' + str(action))
        #     print('reward: ' + str(reward))
        #     print('total_reward: ' + str(total_reward))
        #     print('\n\n')


        if done or elapsed_time >= time_limit_seconds:
            done = True
            steps.append(i+1)
            total_episodes.append(j)
            commulative_rewards.append(total_reward)
            print('total episodes: ' + str(i))
            print('total time: ' + str(elapsed_time))
            print('total steps to complete the episode: ' + str(j))
            print('reward for current state: ' + str(reward))
            print('reward for this episode: ' + str(total_reward))
            print('\n')
            break


# Close the environment
env.close()
# Out:
# total episodes: 0
# total time: 0.9455957412719727
# total steps to complete the episode: 128
# reward for current state: -100
# reward for this episode: -682.2459425903135
#
#
# total episodes: 1
# total time: 0.25121307373046875
# total steps to complete the episode: 74
# reward for current state: -100
# reward for this episode: -192.4382330421926
#
#
# total episodes: 2
# total time: 0.23803377151489258
# total steps to complete the episode: 73
# reward for current state: -100
# reward for this episode: -161.78613940307184
#
#
# total episodes: 3
# total time: 0.25391054153442383
# total steps to complete the episode: 74
# reward for current state: -100
# reward for this episode: -122.89152362171002
#
#
# total episodes: 4
# total time: 0.17703819274902344
# total steps to complete the episode: 57
# reward for current state: -100
# reward for this episode: -120.87163908584327
#
#
# total episodes: 5
# total time: 0.21537375450134277
# total steps to complete the episode: 69
# reward for current state: -100
# reward for this episode: -113.70234136252259
#
#
# total episodes: 6
# total time: 0.20804214477539062
# total steps to complete the episode: 65
# reward for current state: -100
# reward for this episode: -138.12192469862828
#
#
# total episodes: 7
# total time: 0.22864675521850586
# total steps to complete the episode: 66
# reward for current state: -100
# reward for this episode: -147.65900324702113
#
#
# total episodes: 8
# total time: 0.30760693550109863
# total steps to complete the episode: 89
# reward for current state: -100
# reward for this episode: -143.2545362039059
#
#
# total episodes: 9
# total time: 0.22384166717529297
# total steps to complete the episode: 72
# reward for current state: -100
# reward for this episode: -147.21357876856285
#
#
# total episodes: 10
# total time: 0.2891225814819336
# total steps to complete the episode: 92
# reward for current state: -100
# reward for this episode: -102.51014461091336
#
#
# total episodes: 11
# total time: 0.2139580249786377
# total steps to complete the episode: 66
# reward for current state: -100
# reward for this episode: -255.44110007809994
#
#
# total episodes: 12
# total time: 0.20456409454345703
# total steps to complete the episode: 59
# reward for current state: -100
# reward for this episode: -110.23732644455261
#
#
# total episodes: 13
# total time: 0.22615885734558105
# total steps to complete the episode: 67
# reward for current state: -100
# reward for this episode: -490.61988989217804
#
#
# total episodes: 14
# total time: 0.18858838081359863
# total steps to complete the episode: 59
# reward for current state: -100
# reward for this episode: -138.22299959518608
#
#
# total episodes: 15
# total time: 0.29842352867126465
# total steps to complete the episode: 94
# reward for current state: -100
# reward for this episode: -193.85085794774386
#
#
# total episodes: 16
# total time: 1.9289569854736328
# total steps to complete the episode: 522
# reward for current state: -100
# reward for this episode: -254.0750392306477
#
#
# total episodes: 17
# total time: 1.5963449478149414
# total steps to complete the episode: 415
# reward for current state: -100
# reward for this episode: -112.05332115394742
#
#
# total episodes: 18
# total time: 1.2479772567749023
# total steps to complete the episode: 349
# reward for current state: -100
# reward for this episode: -244.60915382775616
#
#
# total episodes: 19
# total time: 1.3708715438842773
# total steps to complete the episode: 348
# reward for current state: -100
# reward for this episode: -453.12175158455693
#
#
# total episodes: 20
# total time: 0.8408806324005127
# total steps to complete the episode: 172
# reward for current state: -100
# reward for this episode: -70.85862146846443
#
#
# total episodes: 21
# total time: 4.8010828495025635
# total steps to complete the episode: 1020
# reward for current state: -100
# reward for this episode: -340.2061289270323
#
#
# total episodes: 22
# total time: 0.930539608001709
# total steps to complete the episode: 267
# reward for current state: -100
# reward for this episode: -272.34805263710234
#
#
# total episodes: 23
# total time: 0.6233737468719482
# total steps to complete the episode: 192
# reward for current state: -100
# reward for this episode: -213.64647071574183
#
#
# total episodes: 24
# total time: 0.8970870971679688
# total steps to complete the episode: 256
# reward for current state: -100
# reward for this episode: -107.27331313595676
#
#
# total episodes: 25
# total time: 1.0035040378570557
# total steps to complete the episode: 286
# reward for current state: -100
# reward for this episode: -188.91134942818042
#
#
# total episodes: 26
# total time: 1.606450080871582
# total steps to complete the episode: 422
# reward for current state: -100
# reward for this episode: -381.9468882096807
#
#
# total episodes: 27
# total time: 0.7522339820861816
# total steps to complete the episode: 227
# reward for current state: -100
# reward for this episode: -653.7262113697767
#
#
# total episodes: 28
# total time: 0.9473929405212402
# total steps to complete the episode: 232
# reward for current state: -100
# reward for this episode: -211.62634224313769
#
#
# total episodes: 29
# total time: 2.0373594760894775
# total steps to complete the episode: 372
# reward for current state: -100
# reward for this episode: -618.5562437311203
#
#
# total episodes: 30
# total time: 1.1670336723327637
# total steps to complete the episode: 306
# reward for current state: -100
# reward for this episode: -297.9235447565014
#
#
# total episodes: 31
# total time: 1.8347015380859375
# total steps to complete the episode: 489
# reward for current state: -100
# reward for this episode: -302.13173641291587
#
#
# total episodes: 32
# total time: 1.8852851390838623
# total steps to complete the episode: 471
# reward for current state: -100
# reward for this episode: -392.7608265698285
#
#
# total episodes: 33
# total time: 1.428774356842041
# total steps to complete the episode: 391
# reward for current state: -100
# reward for this episode: -134.23988523837016
#
#
# total episodes: 34
# total time: 1.3899741172790527
# total steps to complete the episode: 362
# reward for current state: -100
# reward for this episode: -403.27071689416084
#
#
# total episodes: 35
# total time: 1.3659000396728516
# total steps to complete the episode: 374
# reward for current state: -100
# reward for this episode: -341.5510890075592
#
#
# total episodes: 36
# total time: 1.3479907512664795
# total steps to complete the episode: 318
# reward for current state: -100
# reward for this episode: -250.8752362628787
#
#
# total episodes: 37
# total time: 3.5263664722442627
# total steps to complete the episode: 725
# reward for current state: -100
# reward for this episode: -299.37062958208514
#
#
# total episodes: 38
# total time: 11.634651184082031
# total steps to complete the episode: 1968
# reward for current state: -100
# reward for this episode: -631.2590963160219
#
#
# total episodes: 39
# total time: 1.6830129623413086
# total steps to complete the episode: 440
# reward for current state: -100
# reward for this episode: -277.9134629752448
#
#
# total episodes: 40
# total time: 1.0497949123382568
# total steps to complete the episode: 295
# reward for current state: -100
# reward for this episode: -282.6922757854838
#
#
# total episodes: 41
# total time: 0.95298171043396
# total steps to complete the episode: 243
# reward for current state: -100
# reward for this episode: -24.91481906904042
#
#
# total episodes: 42
# total time: 1.2780413627624512
# total steps to complete the episode: 340
# reward for current state: -100
# reward for this episode: -355.6357521247603
#
#
# total episodes: 43
# total time: 0.9300920963287354
# total steps to complete the episode: 264
# reward for current state: -100
# reward for this episode: -293.5381674972364
#
#
# total episodes: 44
# total time: 1.0472581386566162
# total steps to complete the episode: 285
# reward for current state: -100
# reward for this episode: -327.1638389572503
#
#
# total episodes: 45
# total time: 0.9813985824584961
# total steps to complete the episode: 270
# reward for current state: -100
# reward for this episode: -404.38848970474487
#
#
# total episodes: 46
# total time: 0.9248619079589844
# total steps to complete the episode: 260
# reward for current state: -100
# reward for this episode: -325.569369004828
#
#
# total episodes: 47
# total time: 1.4604780673980713
# total steps to complete the episode: 300
# reward for current state: -100
# reward for this episode: -273.00720730489707
#
#
# total episodes: 48
# total time: 1.1140530109405518
# total steps to complete the episode: 209
# reward for current state: -100
# reward for this episode: -294.5404057100037
#
#
# total episodes: 49
# total time: 1.1121528148651123
# total steps to complete the episode: 286
# reward for current state: -100
# reward for this episode: -59.0754046583854
#
#
# total episodes: 50
# total time: 1.022369146347046
# total steps to complete the episode: 278
# reward for current state: -100
# reward for this episode: -187.50526569543766
#
#
# total episodes: 51
# total time: 1.0304555892944336
# total steps to complete the episode: 279
# reward for current state: -100
# reward for this episode: -348.51321135222344
#
#
# total episodes: 52
# total time: 30.006569862365723
# total steps to complete the episode: 3011
# reward for current state: -3.8220198075447653
# reward for this episode: -351.3413299535562
#
#
# total episodes: 53
# total time: 10.399909734725952
# total steps to complete the episode: 1672
# reward for current state: -100
# reward for this episode: -657.2382937599269
#
#
# total episodes: 54
# total time: 1.2204501628875732
# total steps to complete the episode: 310
# reward for current state: -100
# reward for this episode: -320.7019301579151
#
#
# total episodes: 55
# total time: 1.5230388641357422
# total steps to complete the episode: 410
# reward for current state: -100
# reward for this episode: -284.84672401270393
#
#
# total episodes: 56
# total time: 7.3481526374816895
# total steps to complete the episode: 1268
# reward for current state: -100
# reward for this episode: -460.3744417899707
#
#
# total episodes: 57
# total time: 0.9746246337890625
# total steps to complete the episode: 275
# reward for current state: -100
# reward for this episode: -246.52780709570118
#
#
# total episodes: 58
# total time: 0.1793680191040039
# total steps to complete the episode: 56
# reward for current state: -100
# reward for this episode: -133.7040761760012
#
#
# total episodes: 59
# total time: 1.2437193393707275
# total steps to complete the episode: 348
# reward for current state: -100
# reward for this episode: -247.50031059402207
#
#
# total episodes: 60
# total time: 30.01793646812439
# total steps to complete the episode: 2884
# reward for current state: 3.24197810493238
# reward for this episode: -340.2364403118301
#
#
# total episodes: 61
# total time: 30.011111974716187
# total steps to complete the episode: 2779
# reward for current state: 1.0728848667189907
# reward for this episode: -299.21951039149457
#
#
# total episodes: 62
# total time: 0.8621611595153809
# total steps to complete the episode: 241
# reward for current state: -100
# reward for this episode: -19.363792900855614
#
#
# total episodes: 63
# total time: 1.0966713428497314
# total steps to complete the episode: 305
# reward for current state: -100
# reward for this episode: -258.61687726215973
#
#
# total episodes: 64
# total time: 30.008350372314453
# total steps to complete the episode: 3615
# reward for current state: 1.7415920359359742
# reward for this episode: -485.7572533545707
#
#
# total episodes: 65
# total time: 1.3987584114074707
# total steps to complete the episode: 333
# reward for current state: -100
# reward for this episode: -396.5006530522012
#
#
# total episodes: 66
# total time: 28.807497262954712
# total steps to complete the episode: 3883
# reward for current state: -100
# reward for this episode: -911.1275113116099
#
#
# total episodes: 67
# total time: 0.6881301403045654
# total steps to complete the episode: 211
# reward for current state: -100
# reward for this episode: -255.42812602473867
#
#
# total episodes: 68
# total time: 1.197871446609497
# total steps to complete the episode: 337
# reward for current state: -100
# reward for this episode: -262.6642923175566
#
#
# total episodes: 69
# total time: 1.0075526237487793
# total steps to complete the episode: 274
# reward for current state: -100
# reward for this episode: -4.5650259381411615
#
#
# total episodes: 70
# total time: 1.0939841270446777
# total steps to complete the episode: 309
# reward for current state: -100
# reward for this episode: -258.6914861765515
#
#
# total episodes: 71
# total time: 1.0723321437835693
# total steps to complete the episode: 308
# reward for current state: -100
# reward for this episode: -420.529498458708
#
#
# total episodes: 72
# total time: 1.5789604187011719
# total steps to complete the episode: 315
# reward for current state: -100
# reward for this episode: -275.0890332523188
#
#
# total episodes: 73
# total time: 13.450676202774048
# total steps to complete the episode: 2129
# reward for current state: -100
# reward for this episode: -604.7923437448383
#
#
# total episodes: 74
# total time: 1.0731916427612305
# total steps to complete the episode: 302
# reward for current state: -100
# reward for this episode: -191.34775489302393
#
#
# total episodes: 75
# total time: 1.2679932117462158
# total steps to complete the episode: 359
# reward for current state: -100
# reward for this episode: -79.77881603758387
#
#
# total episodes: 76
# total time: 0.45795440673828125
# total steps to complete the episode: 144
# reward for current state: -100
# reward for this episode: -101.85249175225758
#
#
# total episodes: 77
# total time: 1.945077657699585
# total steps to complete the episode: 480
# reward for current state: -100
# reward for this episode: -108.12338038511353
#
#
# total episodes: 78
# total time: 1.0240604877471924
# total steps to complete the episode: 306
# reward for current state: -100
# reward for this episode: -197.3819259322658
#
#
# total episodes: 79
# total time: 3.5958573818206787
# total steps to complete the episode: 749
# reward for current state: -100
# reward for this episode: -355.68424701330355
#
#
# total episodes: 80
# total time: 2.264909267425537
# total steps to complete the episode: 463
# reward for current state: -100
# reward for this episode: -269.5614986161894
#
#
# total episodes: 81
# total time: 12.844794273376465
# total steps to complete the episode: 2271
# reward for current state: -100
# reward for this episode: -691.757268561423
#
#
# total episodes: 82
# total time: 1.1427388191223145
# total steps to complete the episode: 291
# reward for current state: -100
# reward for this episode: -122.8875706165979
#
#
# total episodes: 83
# total time: 1.6267950534820557
# total steps to complete the episode: 419
# reward for current state: -100
# reward for this episode: -100.99751991240892
#
#
# total episodes: 84
# total time: 0.8250534534454346
# total steps to complete the episode: 241
# reward for current state: -100
# reward for this episode: -27.463447897356588
#
#
# total episodes: 85
# total time: 1.020897626876831
# total steps to complete the episode: 299
# reward for current state: -100
# reward for this episode: -171.89353418942
#
#
# total episodes: 86
# total time: 0.6240394115447998
# total steps to complete the episode: 191
# reward for current state: -100
# reward for this episode: -189.31105697121313
#
#
# total episodes: 87
# total time: 5.094821453094482
# total steps to complete the episode: 1111
# reward for current state: -100
# reward for this episode: -466.4454430424066
#
#
# total episodes: 88
# total time: 1.1722571849822998
# total steps to complete the episode: 235
# reward for current state: -100
# reward for this episode: -397.91933615212315
#
#
# total episodes: 89
# total time: 1.2789075374603271
# total steps to complete the episode: 233
# reward for current state: -100
# reward for this episode: -379.4549814330315
#
#
# total episodes: 90
# total time: 0.6799514293670654
# total steps to complete the episode: 183
# reward for current state: -100
# reward for this episode: -408.0227172184273
#
#
# total episodes: 91
# total time: 0.5842843055725098
# total steps to complete the episode: 169
# reward for current state: -100
# reward for this episode: -378.88210260470447
#
#
# total episodes: 92
# total time: 0.6593754291534424
# total steps to complete the episode: 192
# reward for current state: -100
# reward for this episode: -94.47098435019763
#
#
# total episodes: 93
# total time: 0.8579025268554688
# total steps to complete the episode: 251
# reward for current state: -100
# reward for this episode: -43.238979334393164
#
#
# total episodes: 94
# total time: 1.4785799980163574
# total steps to complete the episode: 384
# reward for current state: -100
# reward for this episode: -252.79886604051094
#
#
# total episodes: 95
# total time: 1.5316247940063477
# total steps to complete the episode: 431
# reward for current state: -100
# reward for this episode: -115.95309526283852
#
#
# total episodes: 96
# total time: 30.000301361083984
# total steps to complete the episode: 2827
# reward for current state: 0.7073924349669956
# reward for this episode: -317.3771869648908
#
#
# total episodes: 97
# total time: 1.7183911800384521
# total steps to complete the episode: 372
# reward for current state: -100
# reward for this episode: -277.6563812111981
#
#
# total episodes: 98
# total time: 0.8334593772888184
# total steps to complete the episode: 244
# reward for current state: -100
# reward for this episode: -237.2286179382666
#
#
# total episodes: 99
# total time: 1.0810742378234863
# total steps to complete the episode: 307
# reward for current state: -100
# reward for this episode: -57.58656121554211
#
#
# total episodes: 100
# total time: 0.8822524547576904
# total steps to complete the episode: 257
# reward for current state: -100
# reward for this episode: -297.63666395845814
#
#
# total episodes: 101
# total time: 1.16558837890625
# total steps to complete the episode: 322
# reward for current state: -100
# reward for this episode: -249.91967544412526
#
#
# total episodes: 102
# total time: 0.7899069786071777
# total steps to complete the episode: 222
# reward for current state: -100
# reward for this episode: -215.59340891883323
#
#
# total episodes: 103
# total time: 0.973109245300293
# total steps to complete the episode: 276
# reward for current state: -100
# reward for this episode: -392.437424719703
#
#
# total episodes: 104
# total time: 1.3578543663024902
# total steps to complete the episode: 387
# reward for current state: -100
# reward for this episode: -216.34645663470405
#
#
# total episodes: 105
# total time: 1.0514087677001953
# total steps to complete the episode: 303
# reward for current state: -100
# reward for this episode: -328.27905307824074
#
#
# total episodes: 106
# total time: 0.9175264835357666
# total steps to complete the episode: 230
# reward for current state: -100
# reward for this episode: -193.52813137651538
#
#
# total episodes: 107
# total time: 30.006085872650146
# total steps to complete the episode: 3022
# reward for current state: -1.5751323679085896
# reward for this episode: -358.27065383095663
#
#
# total episodes: 108
# total time: 30.004719972610474
# total steps to complete the episode: 2814
# reward for current state: -1.5946824850301213
# reward for this episode: -284.3449981777366
#
#
# total episodes: 109
# total time: 0.9353892803192139
# total steps to complete the episode: 262
# reward for current state: -100
# reward for this episode: -175.5269175111057
#
#
# total episodes: 110
# total time: 0.9383413791656494
# total steps to complete the episode: 265
# reward for current state: -100
# reward for this episode: -366.329884946073
#
#
# total episodes: 111
# total time: 1.4663467407226562
# total steps to complete the episode: 310
# reward for current state: -100
# reward for this episode: -23.429634186607444
#
#
# total episodes: 112
# total time: 1.4734885692596436
# total steps to complete the episode: 288
# reward for current state: -100
# reward for this episode: -205.64105012382046
#
#
# total episodes: 113
# total time: 1.0176753997802734
# total steps to complete the episode: 280
# reward for current state: -100
# reward for this episode: -286.30715378590753
#
#
# total episodes: 114
# total time: 0.6542880535125732
# total steps to complete the episode: 193
# reward for current state: -100
# reward for this episode: -97.34267318523281
#
#
# total episodes: 115
# total time: 0.9007782936096191
# total steps to complete the episode: 261
# reward for current state: -100
# reward for this episode: -245.54740684904996
#
#
# total episodes: 116
# total time: 1.8886752128601074
# total steps to complete the episode: 485
# reward for current state: -100
# reward for this episode: -351.6530026847193
#
#
# total episodes: 117
# total time: 0.9657907485961914
# total steps to complete the episode: 265
# reward for current state: -100
# reward for this episode: -251.1476844266501
#
#
# total episodes: 118
# total time: 0.8897943496704102
# total steps to complete the episode: 250
# reward for current state: -100
# reward for this episode: -406.22044289060443
#
#
# total episodes: 119
# total time: 1.4339098930358887
# total steps to complete the episode: 384
# reward for current state: -100
# reward for this episode: -252.65044026896405
#
#
# total episodes: 120
# total time: 0.9775986671447754
# total steps to complete the episode: 272
# reward for current state: -100
# reward for this episode: -307.9477806742115
#
#
# total episodes: 121
# total time: 1.3304429054260254
# total steps to complete the episode: 330
# reward for current state: -100
# reward for this episode: -234.48397773232645
#
#
# total episodes: 122
# total time: 2.284789800643921
# total steps to complete the episode: 435
# reward for current state: -100
# reward for this episode: -412.6690526816938
#
#
# total episodes: 123
# total time: 0.8170781135559082
# total steps to complete the episode: 235
# reward for current state: -100
# reward for this episode: -23.748779651514738
#
#
# total episodes: 124
# total time: 30.019325494766235
# total steps to complete the episode: 2901
# reward for current state: 9.491370007170406
# reward for this episode: -347.2950342352658
#
#
# total episodes: 125
# total time: 0.7436861991882324
# total steps to complete the episode: 215
# reward for current state: -100
# reward for this episode: -183.03231454613822
#
#
# total episodes: 126
# total time: 0.7899246215820312
# total steps to complete the episode: 212
# reward for current state: -100
# reward for this episode: -239.84002755462433
#
#
# total episodes: 127
# total time: 0.6558198928833008
# total steps to complete the episode: 193
# reward for current state: -100
# reward for this episode: 9.671310339890866
#
#
# total episodes: 128
# total time: 1.307337760925293
# total steps to complete the episode: 346
# reward for current state: -100
# reward for this episode: -336.3456675887514
#
#
# total episodes: 129
# total time: 1.1338376998901367
# total steps to complete the episode: 230
# reward for current state: -100
# reward for this episode: -334.2702247490499
#
#
# total episodes: 130
# total time: 30.006213903427124
# total steps to complete the episode: 3744
# reward for current state: -2.7163692565096285
# reward for this episode: -512.1002264709668
#
#
# total episodes: 131
# total time: 1.1974024772644043
# total steps to complete the episode: 332
# reward for current state: -100
# reward for this episode: -273.5090765146406
#
#
# total episodes: 132
# total time: 1.0546410083770752
# total steps to complete the episode: 303
# reward for current state: -100
# reward for this episode: -244.23983139209733
#
#
# total episodes: 133
# total time: 0.9036386013031006
# total steps to complete the episode: 251
# reward for current state: -100
# reward for this episode: -209.8339797440197
#
#
# total episodes: 134
# total time: 0.7869858741760254
# total steps to complete the episode: 233
# reward for current state: -100
# reward for this episode: -53.83285176719072
#
#
# total episodes: 135
# total time: 30.0088312625885
# total steps to complete the episode: 3105
# reward for current state: -2.032934184099068
# reward for this episode: -397.0241084298682
#
#
# total episodes: 136
# total time: 4.741948366165161
# total steps to complete the episode: 936
# reward for current state: -100
# reward for this episode: -354.5266180111514
#
#
# total episodes: 137
# total time: 1.3054864406585693
# total steps to complete the episode: 349
# reward for current state: -100
# reward for this episode: -56.51882894084436
#
#
# total episodes: 138
# total time: 1.0594019889831543
# total steps to complete the episode: 284
# reward for current state: -100
# reward for this episode: -225.63498570692246
#
#
# total episodes: 139
# total time: 30.004091262817383
# total steps to complete the episode: 3075
# reward for current state: 1.3885177795084405
# reward for this episode: -322.9942219002469
#
#
# total episodes: 140
# total time: 1.0192835330963135
# total steps to complete the episode: 302
# reward for current state: -100
# reward for this episode: -243.01493688259268
#
#
# total episodes: 141
# total time: 30.003140211105347
# total steps to complete the episode: 4006
# reward for current state: 1.9799648946029091
# reward for this episode: -516.6663560741298
#
#
# total episodes: 142
# total time: 30.02103018760681
# total steps to complete the episode: 2806
# reward for current state: -1.8742391397532094
# reward for this episode: -319.14445436778516
#
#
# total episodes: 143
# total time: 1.260150671005249
# total steps to complete the episode: 345
# reward for current state: -100
# reward for this episode: -267.01109094659296
#
#
# total episodes: 144
# total time: 1.247706413269043
# total steps to complete the episode: 338
# reward for current state: -100
# reward for this episode: -82.01699745513892
#
#
# total episodes: 145
# total time: 0.7552731037139893
# total steps to complete the episode: 218
# reward for current state: -100
# reward for this episode: -253.40647992396865
#
#
# total episodes: 146
# total time: 30.010777711868286
# total steps to complete the episode: 3153
# reward for current state: -0.7023596657064359
# reward for this episode: -354.6125852634658
#
#
# total episodes: 147
# total time: 0.6819591522216797
# total steps to complete the episode: 193
# reward for current state: -100
# reward for this episode: -190.07260680134368
#
#
# total episodes: 148
# total time: 1.5904052257537842
# total steps to complete the episode: 353
# reward for current state: -100
# reward for this episode: -266.58826879101684
#
#
# total episodes: 149
# total time: 1.547394037246704
# total steps to complete the episode: 300
# reward for current state: -100
# reward for this episode: -230.8902865759043
#
#
# total episodes: 150
# total time: 1.0581490993499756
# total steps to complete the episode: 294
# reward for current state: -100
# reward for this episode: -165.95082276645755
#
#
# total episodes: 151
# total time: 0.6792972087860107
# total steps to complete the episode: 207
# reward for current state: -100
# reward for this episode: -185.3884590107365
#
#
# total episodes: 152
# total time: 1.7500240802764893
# total steps to complete the episode: 467
# reward for current state: -100
# reward for this episode: -275.91170900499174
#
#
# total episodes: 153
# total time: 0.9559159278869629
# total steps to complete the episode: 278
# reward for current state: -100
# reward for this episode: -257.9767464450863
#
#
# total episodes: 154
# total time: 0.8426949977874756
# total steps to complete the episode: 240
# reward for current state: -100
# reward for this episode: -323.65329696278195
#
#
# total episodes: 155
# total time: 30.014806985855103
# total steps to complete the episode: 3924
# reward for current state: -0.4308033503162736
# reward for this episode: -518.2863830304037
#
#
# total episodes: 156
# total time: 30.017642736434937
# total steps to complete the episode: 2875
# reward for current state: 2.7908820529340566
# reward for this episode: -307.5608755918713
#
#
# total episodes: 157
# total time: 30.01127791404724
# total steps to complete the episode: 3433
# reward for current state: 11.967246941514553
# reward for this episode: -403.36666025623236
#
#
# total episodes: 158
# total time: 0.7718315124511719
# total steps to complete the episode: 234
# reward for current state: -100
# reward for this episode: -122.35390600768115
#
#
# total episodes: 159
# total time: 0.6333954334259033
# total steps to complete the episode: 190
# reward for current state: -100
# reward for this episode: -316.2012504933557
#
#
# total episodes: 160
# total time: 0.46608924865722656
# total steps to complete the episode: 109
# reward for current state: -100
# reward for this episode: -196.01510246088867
#
#
# total episodes: 161
# total time: 1.8751614093780518
# total steps to complete the episode: 342
# reward for current state: -100
# reward for this episode: -237.7186739431044
#
#
# total episodes: 162
# total time: 1.090395212173462
# total steps to complete the episode: 288
# reward for current state: -100
# reward for this episode: -200.04787111582604
#
#
# total episodes: 163
# total time: 0.8205320835113525
# total steps to complete the episode: 237
# reward for current state: -100
# reward for this episode: -223.7130620966995
#
#
# total episodes: 164
# total time: 0.9168477058410645
# total steps to complete the episode: 258
# reward for current state: -100
# reward for this episode: -163.0797340037677
#
#
# total episodes: 165
# total time: 0.6019189357757568
# total steps to complete the episode: 183
# reward for current state: -100
# reward for this episode: -77.98450024934368
#
#
# total episodes: 166
# total time: 30.000121355056763
# total steps to complete the episode: 3443
# reward for current state: -0.8288869824520251
# reward for this episode: -408.6827686312314
#
#
# total episodes: 167
# total time: 0.9178774356842041
# total steps to complete the episode: 251
# reward for current state: -100
# reward for this episode: -234.15447821623138
#
#
# total episodes: 168
# total time: 0.9054965972900391
# total steps to complete the episode: 240
# reward for current state: -100
# reward for this episode: -184.04539155246567
#
#
# total episodes: 169
# total time: 1.8485524654388428
# total steps to complete the episode: 346
# reward for current state: -100
# reward for this episode: -292.31295519636285
#
#
# total episodes: 170
# total time: 4.174803972244263
# total steps to complete the episode: 983
# reward for current state: -100
# reward for this episode: -447.5201256977392
#
#
# total episodes: 171
# total time: 0.8649981021881104
# total steps to complete the episode: 249
# reward for current state: -100
# reward for this episode: -243.89624244607026
#
#
# total episodes: 172
# total time: 0.9709601402282715
# total steps to complete the episode: 277
# reward for current state: -100
# reward for this episode: -232.76726486583937
#
#
# total episodes: 173
# total time: 1.007542610168457
# total steps to complete the episode: 293
# reward for current state: -100
# reward for this episode: -209.90265055750132
#
#
# total episodes: 174
# total time: 30.00661587715149
# total steps to complete the episode: 3176
# reward for current state: 1.9083635478020085
# reward for this episode: -364.9218435903044
#
#
# total episodes: 175
# total time: 1.1261827945709229
# total steps to complete the episode: 273
# reward for current state: -100
# reward for this episode: -260.80056644786583
#
#
# total episodes: 176
# total time: 0.5470354557037354
# total steps to complete the episode: 166
# reward for current state: -100
# reward for this episode: -264.4658500785122
#
#
# total episodes: 177
# total time: 0.854459285736084
# total steps to complete the episode: 255
# reward for current state: -100
# reward for this episode: -18.874063054311492
#
#
# total episodes: 178
# total time: 0.8350579738616943
# total steps to complete the episode: 239
# reward for current state: -100
# reward for this episode: -229.94211532767395
#
#
# total episodes: 179
# total time: 0.8240435123443604
# total steps to complete the episode: 244
# reward for current state: -100
# reward for this episode: -24.755859082124914
#
#
# total episodes: 180
# total time: 0.953052282333374
# total steps to complete the episode: 268
# reward for current state: -100
# reward for this episode: -50.36113754115952
#
#
# total episodes: 181
# total time: 1.8839960098266602
# total steps to complete the episode: 480
# reward for current state: -100
# reward for this episode: -27.976069078524915
#
#
# total episodes: 182
# total time: 1.0736303329467773
# total steps to complete the episode: 298
# reward for current state: -100
# reward for this episode: -226.16325624871456
#
#
# total episodes: 183
# total time: 1.3972597122192383
# total steps to complete the episode: 366
# reward for current state: -100
# reward for this episode: -117.1745868627647
#
#
# total episodes: 184
# total time: 30.011904001235962
# total steps to complete the episode: 3483
# reward for current state: -1.2512364767704327
# reward for this episode: -443.7245534488203
#
#
# total episodes: 185
# total time: 3.12788987159729
# total steps to complete the episode: 693
# reward for current state: -100
# reward for this episode: -242.68721542025028
#
#
# total episodes: 186
# total time: 0.7062859535217285
# total steps to complete the episode: 213
# reward for current state: -100
# reward for this episode: -192.1769781512999
#
#
# total episodes: 187
# total time: 1.0884873867034912
# total steps to complete the episode: 303
# reward for current state: -100
# reward for this episode: -220.65665677893304
#
#
# total episodes: 188
# total time: 0.86246657371521
# total steps to complete the episode: 245
# reward for current state: -100
# reward for this episode: -228.80890082904537
#
#
# total episodes: 189
# total time: 30.004596948623657
# total steps to complete the episode: 3270
# reward for current state: 0.5873216588535126
# reward for this episode: -409.350449528708
#
#
# total episodes: 190
# total time: 0.6736958026885986
# total steps to complete the episode: 200
# reward for current state: -100
# reward for this episode: -11.180920239368248
#
#
# total episodes: 191
# total time: 1.090590476989746
# total steps to complete the episode: 310
# reward for current state: -100
# reward for this episode: -71.26439853622666
#
#
# total episodes: 192
# total time: 1.041123628616333
# total steps to complete the episode: 300
# reward for current state: -100
# reward for this episode: -256.7995570570966
#
#
# total episodes: 193
# total time: 1.127971887588501
# total steps to complete the episode: 313
# reward for current state: -100
# reward for this episode: -64.5260157332957
#
#
# total episodes: 194
# total time: 1.1302299499511719
# total steps to complete the episode: 301
# reward for current state: -100
# reward for this episode: -9.812214953447167
#
#
# total episodes: 195
# total time: 30.006386280059814
# total steps to complete the episode: 2925
# reward for current state: -2.0209203288193796
# reward for this episode: -327.924886495191
#
#
# total episodes: 196
# total time: 1.6694767475128174
# total steps to complete the episode: 326
# reward for current state: -100
# reward for this episode: -64.79083914024686
#
#
# total episodes: 197
# total time: 0.7673184871673584
# total steps to complete the episode: 230
# reward for current state: -100
# reward for this episode: -382.5133850084268
#
#
# total episodes: 198
# total time: 1.154024362564087
# total steps to complete the episode: 329
# reward for current state: -100
# reward for this episode: -267.03954827661244
#
#
# total episodes: 199
# total time: 0.9905374050140381
# total steps to complete the episode: 281
# reward for current state: -100
# reward for this episode: -201.89059302126796
#
#
# total episodes: 200
# total time: 0.9104800224304199
# total steps to complete the episode: 261
# reward for current state: -100
# reward for this episode: -49.410326261448844
#
#
# total episodes: 201
# total time: 1.2263789176940918
# total steps to complete the episode: 344
# reward for current state: -100
# reward for this episode: -251.35104334470404
#
#
# total episodes: 202
# total time: 30.013712882995605
# total steps to complete the episode: 3793
# reward for current state: -2.055884538364099
# reward for this episode: -477.87315694363133
#
#
# total episodes: 203
# total time: 1.1253373622894287
# total steps to complete the episode: 237
# reward for current state: -100
# reward for this episode: -218.5283277136557
#
#
# total episodes: 204
# total time: 30.010165452957153
# total steps to complete the episode: 3222
# reward for current state: -2.6619055260428253
# reward for this episode: -403.3591850385491
#
#
# total episodes: 205
# total time: 0.8530220985412598
# total steps to complete the episode: 246
# reward for current state: -100
# reward for this episode: -265.481023267811
#
#
# total episodes: 206
# total time: 0.4703407287597656
# total steps to complete the episode: 141
# reward for current state: -100
# reward for this episode: -342.0057663420517
#
#
# total episodes: 207
# total time: 0.841594934463501
# total steps to complete the episode: 252
# reward for current state: -100
# reward for this episode: -62.87326891950681
#
#
# total episodes: 208
# total time: 30.017746210098267
# total steps to complete the episode: 3149
# reward for current state: -3.824612952525172
# reward for this episode: -377.45226080892434
#
#
# total episodes: 209
# total time: 1.2427635192871094
# total steps to complete the episode: 270
# reward for current state: -100
# reward for this episode: -217.3891358995806
#
#
# total episodes: 210
# total time: 1.0000596046447754
# total steps to complete the episode: 282
# reward for current state: -100
# reward for this episode: -229.77009357663883
#
#
# total episodes: 211
# total time: 0.9288558959960938
# total steps to complete the episode: 267
# reward for current state: -100
# reward for this episode: -14.637355453787464
#
#
# total episodes: 212
# total time: 0.829115629196167
# total steps to complete the episode: 247
# reward for current state: -100
# reward for this episode: -92.74193778083533
#
#
# total episodes: 213
# total time: 0.8789150714874268
# total steps to complete the episode: 256
# reward for current state: -100
# reward for this episode: -188.86984159233594
#
#
# total episodes: 214
# total time: 30.01018261909485
# total steps to complete the episode: 3876
# reward for current state: -7.398239682069363
# reward for this episode: -540.3603498232633
#
#
# total episodes: 215
# total time: 4.183531999588013
# total steps to complete the episode: 778
# reward for current state: -100
# reward for this episode: -337.55296357313773
#
#
# total episodes: 216
# total time: 1.05686616897583
# total steps to complete the episode: 298
# reward for current state: -100
# reward for this episode: -182.24806508582836
#
#
# total episodes: 217
# total time: 1.2522766590118408
# total steps to complete the episode: 336
# reward for current state: 100
# reward for this episode: 239.82231181392376
#
#
# total episodes: 218
# total time: 0.7647919654846191
# total steps to complete the episode: 236
# reward for current state: -100
# reward for this episode: -41.21852689115063
#
#
# total episodes: 219
# total time: 0.699394941329956
# total steps to complete the episode: 211
# reward for current state: -100
# reward for this episode: -92.29736431008725
#
#
# total episodes: 220
# total time: 0.9307281970977783
# total steps to complete the episode: 268
# reward for current state: -100
# reward for this episode: -178.96963274728387
#
#
# total episodes: 221
# total time: 1.0373213291168213
# total steps to complete the episode: 305
# reward for current state: -100
# reward for this episode: -42.50506564485205
#
#
# total episodes: 222
# total time: 1.1324474811553955
# total steps to complete the episode: 320
# reward for current state: -100
# reward for this episode: 7.689561624026723
#
#
# total episodes: 223
# total time: 0.6943931579589844
# total steps to complete the episode: 172
# reward for current state: -100
# reward for this episode: -7.969118927241226
#
#
# total episodes: 224
# total time: 2.090341091156006
# total steps to complete the episode: 479
# reward for current state: -100
# reward for this episode: -355.9553765200102
#
#
# total episodes: 225
# total time: 1.1912553310394287
# total steps to complete the episode: 227
# reward for current state: -100
# reward for this episode: -15.49716301146593
#
#
# total episodes: 226
# total time: 0.8148062229156494
# total steps to complete the episode: 197
# reward for current state: -100
# reward for this episode: -184.15987157719218
#
#
# total episodes: 227
# total time: 0.6073238849639893
# total steps to complete the episode: 180
# reward for current state: -100
# reward for this episode: -209.0863500618064
#
#
# total episodes: 228
# total time: 30.00565004348755
# total steps to complete the episode: 4079
# reward for current state: -1.957248944599047
# reward for this episode: -585.7859874409312
#
#
# total episodes: 229
# total time: 1.317030668258667
# total steps to complete the episode: 360
# reward for current state: -100
# reward for this episode: -233.13561229241267
#
#
# total episodes: 230
# total time: 0.7106678485870361
# total steps to complete the episode: 217
# reward for current state: -100
# reward for this episode: -263.1324865793076
#
#
# total episodes: 231
# total time: 0.7859907150268555
# total steps to complete the episode: 239
# reward for current state: -100
# reward for this episode: -212.08571538308684
#
#
# total episodes: 232
# total time: 0.8819890022277832
# total steps to complete the episode: 255
# reward for current state: -100
# reward for this episode: 15.998577368911128
#
#
# total episodes: 233
# total time: 1.2369847297668457
# total steps to complete the episode: 257
# reward for current state: -100
# reward for this episode: -15.31891959652539
#
#
# total episodes: 234
# total time: 1.28365159034729
# total steps to complete the episode: 239
# reward for current state: -100
# reward for this episode: -72.45537974654405
#
#
# total episodes: 235
# total time: 0.9520032405853271
# total steps to complete the episode: 281
# reward for current state: -100
# reward for this episode: -249.6823809029961
#
#
# total episodes: 236
# total time: 1.1910219192504883
# total steps to complete the episode: 312
# reward for current state: -100
# reward for this episode: -231.17971436470216
#
#
# total episodes: 237
# total time: 0.8210561275482178
# total steps to complete the episode: 243
# reward for current state: -100
# reward for this episode: 14.668941308583598
#
#
# total episodes: 238
# total time: 0.8786435127258301
# total steps to complete the episode: 256
# reward for current state: -100
# reward for this episode: -17.853382520146454
#
#
# total episodes: 239
# total time: 0.8361260890960693
# total steps to complete the episode: 248
# reward for current state: -100
# reward for this episode: -58.29293407031973
#
#
# total episodes: 240
# total time: 0.8259444236755371
# total steps to complete the episode: 241
# reward for current state: -100
# reward for this episode: -7.223803610710107
#
#
# total episodes: 241
# total time: 30.00224757194519
# total steps to complete the episode: 3884
# reward for current state: -8.65495848357355
# reward for this episode: -512.6986573050212
#
#
# total episodes: 242
# total time: 1.4786615371704102
# total steps to complete the episode: 298
# reward for current state: -100
# reward for this episode: -224.38597431566387
#
#
# total episodes: 243
# total time: 0.9249191284179688
# total steps to complete the episode: 263
# reward for current state: -100
# reward for this episode: -152.5535886330622
#
#
# total episodes: 244
# total time: 0.9678773880004883
# total steps to complete the episode: 286
# reward for current state: -100
# reward for this episode: -155.02643336121469
#
#
# total episodes: 245
# total time: 0.7408735752105713
# total steps to complete the episode: 224
# reward for current state: -100
# reward for this episode: -289.35813459355757
#
#
# total episodes: 246
# total time: 0.48719072341918945
# total steps to complete the episode: 157
# reward for current state: -100
# reward for this episode: -160.0645486907809
#
#
# total episodes: 247
# total time: 0.8715696334838867
# total steps to complete the episode: 262
# reward for current state: -100
# reward for this episode: -248.3552828650484
#
#
# total episodes: 248
# total time: 0.8321025371551514
# total steps to complete the episode: 250
# reward for current state: -100
# reward for this episode: -305.96709412143264
#
#
# total episodes: 249
# total time: 30.00538992881775
# total steps to complete the episode: 2558
# reward for current state: -2.5103384226252494
# reward for this episode: -299.17589778395757
#
#
# total episodes: 250
# total time: 0.6618506908416748
# total steps to complete the episode: 140
# reward for current state: -100
# reward for this episode: -285.91657760640567
#
#
# total episodes: 251
# total time: 1.2115757465362549
# total steps to complete the episode: 247
# reward for current state: -100
# reward for this episode: -190.2513363723479
#
#
# total episodes: 252
# total time: 1.429405689239502
# total steps to complete the episode: 347
# reward for current state: -100
# reward for this episode: -233.69722363138857
#
#
# total episodes: 253
# total time: 2.880709648132324
# total steps to complete the episode: 734
# reward for current state: -100
# reward for this episode: -237.59246371560027
#
#
# total episodes: 254
# total time: 0.9960424900054932
# total steps to complete the episode: 291
# reward for current state: -100
# reward for this episode: -145.09602579367763
#
#
# total episodes: 255
# total time: 1.6395509243011475
# total steps to complete the episode: 435
# reward for current state: -100
# reward for this episode: -378.76458599309285
#
#
# total episodes: 256
# total time: 0.8221762180328369
# total steps to complete the episode: 243
# reward for current state: -100
# reward for this episode: -7.19962778774871
#
#
# total episodes: 257
# total time: 0.6861557960510254
# total steps to complete the episode: 201
# reward for current state: -100
# reward for this episode: -36.49841427107545
#
#
# total episodes: 258
# total time: 0.9628763198852539
# total steps to complete the episode: 282
# reward for current state: -100
# reward for this episode: -227.38199244928808
#
#
# total episodes: 259
# total time: 0.9922549724578857
# total steps to complete the episode: 284
# reward for current state: -100
# reward for this episode: -237.53235941226583
#
#
# total episodes: 260
# total time: 1.1006073951721191
# total steps to complete the episode: 240
# reward for current state: -100
# reward for this episode: -190.91372798159296
#
#
# total episodes: 261
# total time: 1.6271696090698242
# total steps to complete the episode: 313
# reward for current state: -100
# reward for this episode: -233.45760785362867
#
#
# total episodes: 262
# total time: 0.7682051658630371
# total steps to complete the episode: 234
# reward for current state: -100
# reward for this episode: 11.791503169931062
#
#
# total episodes: 263
# total time: 1.0688748359680176
# total steps to complete the episode: 299
# reward for current state: -100
# reward for this episode: -262.1344251940081
#
#
# total episodes: 264
# total time: 0.844745397567749
# total steps to complete the episode: 251
# reward for current state: -100
# reward for this episode: -164.60545343273554
#
#
# total episodes: 265
# total time: 30.00396156311035
# total steps to complete the episode: 2773
# reward for current state: 0.3953730526619122
# reward for this episode: -340.4707833195627
#
#
# total episodes: 266
# total time: 0.6104574203491211
# total steps to complete the episode: 190
# reward for current state: -100
# reward for this episode: -88.82363993970837
#
#
# total episodes: 267
# total time: 0.5371396541595459
# total steps to complete the episode: 172
# reward for current state: -100
# reward for this episode: -302.9770053235361
#
#
# total episodes: 268
# total time: 0.5027668476104736
# total steps to complete the episode: 160
# reward for current state: -100
# reward for this episode: -340.5297334801265
#
#
# total episodes: 269
# total time: 0.7735941410064697
# total steps to complete the episode: 188
# reward for current state: -100
# reward for this episode: -215.36012825878566
#
#
# total episodes: 270
# total time: 1.075544834136963
# total steps to complete the episode: 236
# reward for current state: -100
# reward for this episode: -90.71391496312224
#
#
# total episodes: 271
# total time: 1.1546125411987305
# total steps to complete the episode: 250
# reward for current state: -100
# reward for this episode: -3.7265166665054466
#
#
# total episodes: 272
# total time: 0.7937216758728027
# total steps to complete the episode: 237
# reward for current state: -100
# reward for this episode: -58.49670773332409
#
#
# total episodes: 273
# total time: 30.007883310317993
# total steps to complete the episode: 3496
# reward for current state: -2.013656406749205
# reward for this episode: -443.3876619436528
#
#
# total episodes: 274
# total time: 1.3103623390197754
# total steps to complete the episode: 349
# reward for current state: -100
# reward for this episode: -42.50505904230721
#
#
# total episodes: 275
# total time: 0.8262410163879395
# total steps to complete the episode: 242
# reward for current state: -100
# reward for this episode: -184.27697594884657
#
#
# total episodes: 276
# total time: 0.5516357421875
# total steps to complete the episode: 167
# reward for current state: -100
# reward for this episode: -112.52963598559825
#
#
# total episodes: 277
# total time: 0.7447619438171387
# total steps to complete the episode: 223
# reward for current state: -100
# reward for this episode: -184.29403721294548
#
#
# total episodes: 278
# total time: 30.01078963279724
# total steps to complete the episode: 2730
# reward for current state: -0.9893853731942024
# reward for this episode: -294.03805301878657
#
#
# total episodes: 279
# total time: 0.7083754539489746
# total steps to complete the episode: 212
# reward for current state: -100
# reward for this episode: -158.57750326367812
#
#
# total episodes: 280
# total time: 30.005274534225464
# total steps to complete the episode: 3676
# reward for current state: 1.662977211124429
# reward for this episode: -568.9003312720564
#
#
# total episodes: 281
# total time: 0.8061299324035645
# total steps to complete the episode: 232
# reward for current state: -100
# reward for this episode: -59.16753920525749
#
#
# total episodes: 282
# total time: 1.0251085758209229
# total steps to complete the episode: 281
# reward for current state: -100
# reward for this episode: -160.5488787641044
#
#
# total episodes: 283
# total time: 1.0905771255493164
# total steps to complete the episode: 204
# reward for current state: -100
# reward for this episode: -61.54403624634973
#
#
# total episodes: 284
# total time: 1.2459962368011475
# total steps to complete the episode: 254
# reward for current state: -100
# reward for this episode: -216.88114874456124
#
#
# total episodes: 285
# total time: 30.011207342147827
# total steps to complete the episode: 3083
# reward for current state: 9.09404745345285
# reward for this episode: -392.3724258924147
#
#
# total episodes: 286
# total time: 30.008501052856445
# total steps to complete the episode: 3058
# reward for current state: 0.19096133464740178
# reward for this episode: -379.1323476675572
#
#
# total episodes: 287
# total time: 0.7048854827880859
# total steps to complete the episode: 121
# reward for current state: -100
# reward for this episode: -497.1114205812558
#
#
# total episodes: 288
# total time: 0.8368725776672363
# total steps to complete the episode: 160
# reward for current state: -100
# reward for this episode: -565.8937538198027
#
#
# total episodes: 289
# total time: 0.4556267261505127
# total steps to complete the episode: 120
# reward for current state: -100
# reward for this episode: -574.7305480547113
#
#
# total episodes: 290
# total time: 0.5165081024169922
# total steps to complete the episode: 162
# reward for current state: -100
# reward for this episode: -613.0037736910251
#
#
# total episodes: 291
# total time: 0.5970759391784668
# total steps to complete the episode: 182
# reward for current state: -100
# reward for this episode: -301.4180238478309
#
#
# total episodes: 292
# total time: 0.4175984859466553
# total steps to complete the episode: 133
# reward for current state: -100
# reward for this episode: -397.25866200915686
#
#
# total episodes: 293
# total time: 0.3854966163635254
# total steps to complete the episode: 115
# reward for current state: -100
# reward for this episode: -276.70447413599663
#
#
# total episodes: 294
# total time: 0.372086763381958
# total steps to complete the episode: 118
# reward for current state: -100
# reward for this episode: -281.8002891763013
#
#
# total episodes: 295
# total time: 0.37682652473449707
# total steps to complete the episode: 112
# reward for current state: -100
# reward for this episode: -594.8834606579721
#
#
# total episodes: 296
# total time: 0.9915738105773926
# total steps to complete the episode: 281
# reward for current state: -100
# reward for this episode: -243.52677046399708
#
#
# total episodes: 297
# total time: 0.4374222755432129
# total steps to complete the episode: 135
# reward for current state: -100
# reward for this episode: -302.0835511588276
#
#
# total episodes: 298
# total time: 0.4417996406555176
# total steps to complete the episode: 139
# reward for current state: -100
# reward for this episode: -247.18322569615887
#
#
# total episodes: 299
# total time: 0.9834446907043457
# total steps to complete the episode: 276
# reward for current state: -100
# reward for this episode: -185.18392875820157
#
#
# total episodes: 300
# total time: 0.2257239818572998
# total steps to complete the episode: 64
# reward for current state: -100
# reward for this episode: -38.91832839782441
#
#
# total episodes: 301
# total time: 1.0192875862121582
# total steps to complete the episode: 296
# reward for current state: -100
# reward for this episode: -12.274525351096216
#
#
# total episodes: 302
# total time: 30.014491081237793
# total steps to complete the episode: 2918
# reward for current state: 0.2701136986743993
# reward for this episode: -324.81848811375056
#
#
# total episodes: 303
# total time: 0.7800700664520264
# total steps to complete the episode: 221
# reward for current state: -100
# reward for this episode: -363.16339157850285
#
#
# total episodes: 304
# total time: 0.8612618446350098
# total steps to complete the episode: 252
# reward for current state: -100
# reward for this episode: -30.40722204789745
#
#
# total episodes: 305
# total time: 0.7908868789672852
# total steps to complete the episode: 239
# reward for current state: -100
# reward for this episode: -19.431199428176924
#
#
# total episodes: 306
# total time: 1.041330099105835
# total steps to complete the episode: 303
# reward for current state: -100
# reward for this episode: -217.81560097063144
#
#
# total episodes: 307
# total time: 0.8619999885559082
# total steps to complete the episode: 258
# reward for current state: -100
# reward for this episode: -217.93798327451086
#
#
# total episodes: 308
# total time: 2.1556687355041504
# total steps to complete the episode: 527
# reward for current state: -100
# reward for this episode: -286.68776862510344
#
#
# total episodes: 309
# total time: 0.785846471786499
# total steps to complete the episode: 225
# reward for current state: -100
# reward for this episode: -266.40278802054763
#
#
# total episodes: 310
# total time: 0.8271462917327881
# total steps to complete the episode: 214
# reward for current state: -100
# reward for this episode: -332.12851991529067
#
#
# total episodes: 311
# total time: 0.7184581756591797
# total steps to complete the episode: 201
# reward for current state: -100
# reward for this episode: -255.13175493511312
#
#
# total episodes: 312
# total time: 0.4087851047515869
# total steps to complete the episode: 123
# reward for current state: -100
# reward for this episode: -268.1229887580142
#
#
# total episodes: 313
# total time: 0.8279533386230469
# total steps to complete the episode: 252
# reward for current state: -100
# reward for this episode: -256.76024159349083
#
#
# total episodes: 314
# total time: 1.2634727954864502
# total steps to complete the episode: 249
# reward for current state: -100
# reward for this episode: -68.65178404983064
#
#
# total episodes: 315
# total time: 0.9362802505493164
# total steps to complete the episode: 186
# reward for current state: -100
# reward for this episode: -310.42678941162313
#
#
# total episodes: 316
# total time: 0.692086935043335
# total steps to complete the episode: 175
# reward for current state: -100
# reward for this episode: -504.5949429557416
#
#
# total episodes: 317
# total time: 0.5130550861358643
# total steps to complete the episode: 153
# reward for current state: -100
# reward for this episode: -486.87473556720084
#
#
# total episodes: 318
# total time: 1.1083877086639404
# total steps to complete the episode: 279
# reward for current state: -100
# reward for this episode: -30.68740376679321
#
#
# total episodes: 319
# total time: 0.791205644607544
# total steps to complete the episode: 209
# reward for current state: -100
# reward for this episode: 52.79928882185334
#
#
# total episodes: 320
# total time: 0.6489496231079102
# total steps to complete the episode: 199
# reward for current state: -100
# reward for this episode: -185.70550854808175
#
#
# total episodes: 321
# total time: 0.6903858184814453
# total steps to complete the episode: 202
# reward for current state: -100
# reward for this episode: -280.25679893005696
#
#
# total episodes: 322
# total time: 0.8174929618835449
# total steps to complete the episode: 230
# reward for current state: -100
# reward for this episode: -180.05220792499142
#
#
# total episodes: 323
# total time: 0.9403018951416016
# total steps to complete the episode: 275
# reward for current state: -100
# reward for this episode: -155.8073783175724
#
#
# total episodes: 324
# total time: 1.252591609954834
# total steps to complete the episode: 334
# reward for current state: -100
# reward for this episode: -226.33211419275813
#
#
# total episodes: 325
# total time: 1.0976955890655518
# total steps to complete the episode: 304
# reward for current state: -100
# reward for this episode: -55.56810025031619
#
#
# total episodes: 326
# total time: 0.3251206874847412
# total steps to complete the episode: 101
# reward for current state: -100
# reward for this episode: -210.28916766649164
#
#
# total episodes: 327
# total time: 0.8660705089569092
# total steps to complete the episode: 248
# reward for current state: -100
# reward for this episode: -21.61117499628982
#
#
# total episodes: 328
# total time: 0.8900289535522461
# total steps to complete the episode: 220
# reward for current state: -100
# reward for this episode: -212.77959935936377

# %%
import matplotlib.pyplot as plt

def graph_for_episodes_with_steps():
  x_axis = steps
  y_axis = total_episodes

  plt.plot(x_axis, y_axis)
  plt.xlabel('Steps')
  plt.ylabel('Episodes')
  plt.title('Episodes / Steps')
  plt.show()

def graph_for_rewards_with_steps():
  x_axis = steps
  y_axis = commulative_rewards

  plt.plot(x_axis, y_axis)
  plt.xlabel('Steps')
  plt.ylabel('Commulitive Reward')
  plt.title('Commulitive Reward / Steps')
  plt.show()

graph_for_episodes_with_steps()
graph_for_rewards_with_steps()

# %%
# !ls /content/videos
